# %%
frutas = ["Maça", "Banana", "Laranja"]
print (frutas)
# Out:
# ['Maça', 'Banana', 'Laranja']

# %%
frutas.append("Morango")
print(frutas)
# Out:
# ['Maça', 'Banana', 'Laranja', 'Morango']

# %%
livros = []
livros.append("O Pequeno Príncipe")
livros.append("Dom Quixote")
livros.append("1984")

print(f"Pilha original: {livros}")

livro_removido = livros.pop()

print(f"Livro removido: {livro_removido}")
print(f"Pilha restante: {livros}")
# Out:
# Pilha original: ['O Pequeno Príncipe', 'Dom Quixote', '1984']
# Livro removido: 1984
# Pilha restante: ['O Pequeno Príncipe', 'Dom Quixote']

# %%
clientes = ["Ana", "Bruno", "Carla"]
print(clientes)
# Out:
# ['Ana', 'Bruno', 'Carla']

# %%
clientes.append("Daniel")
print(clientes)
# Out:
# ['Ana', 'Bruno', 'Carla', 'Daniel']

# %%
cliente_atendido = clientes.pop(0)
print(f"Cliente que saiu: {cliente_atendido}")
print(f"Fila restante: {clientes}")
# Out:
# Cliente que saiu: Ana
# Fila restante: ['Bruno', 'Carla', 'Daniel']

# %%
contatos = {
    "Ana": "1234-5678",
    "Bruno": "9876-5432"
}

contatos["Carlos"] = "1122-3344"
print(contatos)
# Out:
# {'Ana': '1234-5678', 'Bruno': '9876-5432', 'Carlos': '1122-3344'}

# %%
print(f"O telefone da Ana é: {contatos['Ana']}")
# Out:
# O telefone da Ana é: 1234-5678
